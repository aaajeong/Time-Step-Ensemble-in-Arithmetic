# %%
! python ./ch07/train_seq2seq.py
# Out:
# 2021-09-15 17:38:37.145104: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-09-15 17:38:37.156454: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fabc1f1f170 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-09-15 17:38:37.156473: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15386954618034927666
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12966170124461250971
# physical_device_desc: "device: XLA_CPU device"
# ]
# [[ 0  1  2 ...  4  5  5]
#  [ 4  8  2 ...  9  3  5]
#  [ 3  4  2 ...  8  5  5]
#  ...
#  [ 8  4 10 ...  7 11  5]
#  [ 0  0  0 ... 11 10  0]
#  [ 8  7 10 ... 11  8  3]]
# ...

# %%
! CUDA_VISIBLE_DEVICES=3  python ./ch07/train_seq2seq.py
# Out:
# 2021-09-15 18:41:20.651393: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-09-15 18:41:20.678340: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2095310000 Hz
# 2021-09-15 18:41:20.680321: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559cdd5e5d60 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-09-15 18:41:20.680351: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-09-15 18:41:20.682187: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-09-15 18:41:20.706732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:87:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# ...

# %%
import cupy as cp
print(cp.__version__)
# Out:
# 8.3.0
